# %% [markdown]
# lateral modes comparision
# ![lateral modes comparision](p1/lat_comparision.png)
# longitudonal modes comparision
# ![longitudonal modes comparision](p1/long_comparisions.png)
#
# Manuever 1
# ![Manuever 1](p1/man1_long_lat.png)
# Manuever 2
# ![Manuever 2](p1/man2_long_lat.png)
